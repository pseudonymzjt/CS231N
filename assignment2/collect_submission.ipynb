# %%
# This notebook is adapted to run in a local container environment.
# No Google Drive mounting is needed.

# TODO: Enter the foldername where you have saved the unzipped
# assignment folder, e.g. '/workspace/code/cs336-workspace/CS231N/assignment2/'
FOLDERNAME = '/workspace/code/cs336-workspace/CS231N/assignment2/'

assert FOLDERNAME is not None, "[!] Enter the foldername."

# %% [markdown]
# # Collect Submission - Zip + Generate PDF
#
# Run this notebook once you have completed all the other notebooks: `BatchNormalization.ipynb`, `Dropout.ipynb`, `ConvolutionalNetworks.ipynb` and `PyTorch.ipynb`, `RNN_Captioning_pytorch.ipynb`.
#
# It will:
#
# * Generate a zip file of your code (`.py` and `.ipynb`) called `a2.zip`.
# * Convert all notebooks into a single PDF file called `assignment.pdf`.
#
# If your submission for this step was successful, you should see the following display message:
#
# `### Done! Please submit a2.zip and the pdfs to Gradescope. ###`
#
# Make sure to download the zip and pdf file locally to your computer, then submit to Gradescope. Congrats on succesfully completing the assignment!

# %%
# %cd $FOLDERNAME
# Install the tools needed to build the PDF if they are not already available.
# (This container runs as root, so no sudo is needed.)
# !which pandoc >/dev/null 2>&1 || apt-get install -y pandoc
# !which xelatex >/dev/null 2>&1 || apt-get install -y texlive-xetex texlive-fonts-recommended texlive-plain-generic texlive-latex-extra
# !which xelatex
# !pip install PyPDF2
# !bash collectSubmission.sh
